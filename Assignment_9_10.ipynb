# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# In univariate analysis we only looked at 1 variable (= 1 column) at a time. In bivariate analysis we will now look at the relation between two variables (= 2 columns).
#
# The type of analysis we can do will once again depend on the types of data of these 2 variables. We look look at:
# - Numerical VS Numerical.
# - Nummerical VS Categorical
# - Categorical VS Categorical

# %% [markdown]
# ## Numerical VS Numerical

# %% [markdown]
# Examples:
# - Age VS Time to takes to run 1 kilometre.
# - Body length VS Shoe size
# - Country Unemployment rate VS Country Happiness Rating
# - Customer Revenue VS Customer Lifetime
# - Game Wishlists VS Game Purchases
# - Student grades VS Student attendance
# - ...

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ![](https://miro.medium.com/max/1000/1*Hh53mOF4Xy4eORjLilKOwA.png "Iris dataset")

# %% [markdown]
# Let's look at the relation between the sepal length and petal length. (Dutch: Kelkblad en bloemblad)

# %%
iris.plot(kind='scatter', x='sepal_length', y='petal_length')

# %% [markdown]
# A useful statistic for calculating the linear relation between two variable is the **Pearson correlation**.
# The Pearson correlation measures the linear relation between two numerical variables. The result is a number between -1 and 1 where
# - -1 indicates a perfect negative linear relation
# - 0 indicates that there is no linear relation
# - 1 indicates a perfect positive linear relation

# %% [markdown]
# ![](https://www.spss-tutorials.com/img/correlation-coefficient-multiple-scatterplots.png "Pearson correlation examples")

# %% [markdown]
# ![](https://cdn1.byjus.com/wp-content/uploads/2019/06/word-image28.png "Pearson correlation formula")

# %%
iris[['sepal_length','petal_length']].corr()
# Out:
#               sepal_length  petal_length
# sepal_length      1.000000      0.871754
# petal_length      0.871754      1.000000

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
irisCorrelations = iris.corr()
irisCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow0_col1 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow0_col2 {
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow0_col3 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow1_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d60ba72e_6799_11eb_8da7_7c2a31ed035erow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
# ...

# %%
iris.plot(kind='scatter', x='sepal_width', y='petal_length')

# %%
import numpy as np

# %%
exampleData = pd.Series(range(100)) + 1
exampleDataNegative = -exampleData
exampleDataDouble = exampleData * 2
exampleDataSquared = exampleData ** 2
exampleDataRoot = exampleData ** 0.5

exampleDataExponential = 2 ** exampleData
exampleDataLog = np.log2(exampleData)

exampleDataWithSmallNoise = exampleData + np.random.randint(low=0, high=10, size=len(exampleData))
exampleDataWithMediumNoise = exampleData + np.random.randint(low=0, high=100, size=len(exampleData))
exampleDataWithHeavyNoise = exampleData + np.random.randint(low=0, high=1000, size=len(exampleData))

exampleDataFrame = pd.DataFrame({'original':exampleData, 'negative':exampleDataNegative, 'double':exampleDataDouble, 'squared':exampleDataSquared, 'root': exampleDataRoot, 'exp':exampleDataExponential, 'log':exampleDataLog, 'noiseSmall': exampleDataWithSmallNoise, 'noiseMedium': exampleDataWithMediumNoise, 'noiseHeavy':exampleDataWithHeavyNoise })

# %%
exampleDataFrame.head()
# Out:
#    original  negative  double  squared      root  exp       log  noiseSmall  \
# 0         1        -1       2        1  1.000000    2  0.000000           9
# 1         2        -2       4        4  1.414214    4  1.000000           4
# 2         3        -3       6        9  1.732051    8  1.584963           8
# 3         4        -4       8       16  2.000000   16  2.000000           5
# 4         5        -5      10       25  2.236068   32  2.321928           7
#
#    noiseMedium  noiseHeavy
# 0           26         123
# 1           46         160
# 2           70         234
# 3           80         312
# 4           29         804

# %%
exampleDataCorrelations = exampleDataFrame.corr()
exampleDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col3 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col4 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col5 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_d64fd48d_6799_11eb_b4c9_7c2a31ed035erow0_col6 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
# ...

# %%
# Excluding a couple of columns because their values are too high to show in the same plot
exampleDataFrame.drop(['exp', 'squared' , 'noiseHeavy'], axis=1).plot(figsize=(15,8))

# %% [markdown]
# ### Portfolio assignment 9
# 25 min: Perform a bivariate analysis on the columns with numerical data in the penguins dataset.
# - Use corr() on the DataFrame to calculate all the correlations. Use the code example above to show the correlation table with colors.
# - Look at the corrrelations. Do they match your expectations?
# - Show a scatter plot for
#  - The strongest positive correlation
#  - The strongest negative correlation
#  - The weakest correlation

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ![](https://www.galapagos.org/wp-content/uploads/2019/04/PenguinMeasurements_BLOGv3.png)

# %%
penguins.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
penguins_color = penguins.corr()
penguins_color.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_ada3e14a_6adc_11eb_93ad_58a023d3f706row0_col0,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row1_col1,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row2_col2,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row0_col1,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row1_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row0_col2,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row2_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row0_col3,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row3_col0{
#             background-color:  #f59c7d;
#             color:  #000000;
#         }#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row1_col2,#T_ada3e14a_6adc_11eb_93ad_58a023d3f706row2_col1{
# ...

# %%
penguins.plot(figsize=(16,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Overzichtelijker zonder de body_mass_g :

# %%
penguins.drop(['body_mass_g'],axis = 1).plot(figsize=(16,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# De correlaties worden weergegeven zoals verwacht, omdat er niet een groot verschil kan zijn in de flipper length, bill depth en bill length. Dit is niet hetzelfde geval voor de body mass. Gewicht is namelijk een meer veranderlijke variabele en die is in de duizenden, integendeel tot de andere variabelen, die maximaal een paar honderd kan zijn. Je ziet hierboven dat de flipper length enigzins een correlatie heeft met de bill length. Als de flipper length omhoog schiet, dan zie je dat ook een beetje bij de bill length.

# %%
penguins.plot(kind='scatter', x='bill_depth_mm', y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# Strongest negative correlation

# %%
penguins.plot(kind='scatter', x='flipper_length_mm', y='body_mass_g')
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
# Strongest positive correlation

# %%
penguins.plot(kind='scatter', x='bill_length_mm', y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %% [markdown]
# Weakest correlation

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Portfolio assignment 10
# 15 min: Perform a bivariate analysis (Pearson correlation and scatter plot) on at least 1 combination of 2 columns with numeric data in the dataset that you chose in portfolio assignment 4. Does the correlation and scatter plot match your expectations? Add your answer to your notebook. Commit the Notebook to your portfolio when you're finished.

# %%
import pandas as pd

movies = pd.read_csv (r'movies.csv')

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_color = movies.corr()
movies_color.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_ad8836b0_6ad7_11eb_b387_58a023d3f706row0_col0,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row1_col1,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row2_col2,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row3_col3,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row4_col4,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row5_col5,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row0_col1,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row1_col0{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row0_col2,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row2_col0{
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row0_col3,#T_ad8836b0_6ad7_11eb_b387_58a023d3f706row3_col0{
#             background-color:  #f08a6c;
#             color:  #000000;
# ...

# %% [markdown]
# ----

# %% [markdown]
# Correlatie zien tussen het aantal votes en revenue.

# %%
movies[['vote_count','revenue']].corr()
# Out:
#             vote_count   revenue
# vote_count    1.000000  0.781487
# revenue       0.781487  1.000000

# %%
movies_color.plot(kind='scatter', x='vote_count', y='revenue')
# Out:
# <AxesSubplot:xlabel='vote_count', ylabel='revenue'>

# %% [markdown]
# Positive correlation: 0.8

# %% [markdown]
# Een hoog budget betekent meestal dat het een bekende film is. Bekende films worden vaker beoordeeld.

# %% [markdown]
# ----

# %% [markdown]
# Correlatie zien tussen het budget en de opbrengst van de films.

# %%
movies[['budget','revenue']].corr()
# Out:
#            budget   revenue
# budget   1.000000  0.730823
# revenue  0.730823  1.000000

# %%
movies_color.plot(kind='scatter', x='revenue', y='budget')
# Out:
# <AxesSubplot:xlabel='revenue', ylabel='budget'>

# %% [markdown]
# Positive correlation: 0.7

# %%
# Excluding a couple of columns because their values are too high to show in the same plot
movies.drop(['id', 'vote_count', 'runtime', 'popularity', 'vote_average'], axis=1).plot(figsize=(18,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Het resultaat is zoals verwacht. Meestal hoe hoger het budget, hoe hoger de revenue. Er zijn enkele uitschieters waarbij het budget hoger is dan de revenue (verlies).

# %% [markdown]
# ----

# %% [markdown]
# Correlatie zien tussen de runtime en populariteit van de films.

# %%
movies[['popularity','runtime']].corr()
# Out:
#             popularity   runtime
# popularity    1.000000  0.225502
# runtime       0.225502  1.000000

# %%
movies_color.plot(kind='scatter', x='runtime', y='popularity')
# Out:
# <AxesSubplot:xlabel='runtime', ylabel='popularity'>

# %% [markdown]
# Positive correlation: 0.2

# %%
# Excluding a couple of columns because their values are too high to show in the same plot
movies.drop(['id', 'vote_count', 'revenue', 'budget', 'vote_average'], axis=1).plot(figsize=(18,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Hier zie je dat er een hele kleine samenhang ligt tussen de populariteit van een film en de afspeelduur. Films die meer an 3 uur lang zijn, zijn meestal niet al te populair. Evenals de 'short films'.
